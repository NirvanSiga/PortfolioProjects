# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
netflix_dataset = pd.read_csv(r"C:\Users\Nirvan\Downloads\NetFlix.csv")
df = netflix_dataset.copy()

df
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
df["director"] = df["director"].fillna("N/A")
df["cast"] = df["cast"].fillna("N/A")
df["country"] = df["country"].fillna("N/A")
df.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           7
# duration         0
# genres           0
# description      0
# dtype: int64

# %%
df.dropna(subset = ["date_added", "rating"], inplace = True)

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df["type"].value_counts(normalize = True) * 100
# Out:
# Movie      69.137709
# TV Show    30.862291
# Name: type, dtype: float64

# %%
df["type"].value_counts(normalize = True).plot(kind='pie', ylabel="", title="Content Type Dsitribution")
plt.show()

# %%
df["country"].value_counts().sort_values(ascending=False).head(6).plot(kind='barh', ylabel="", title="Coutries with most content")
# Out:
# <AxesSubplot:title={'center':'Coutries with most content'}>

# %%
df["genres"].value_counts().head().plot(kind='barh', xlabel="", ylabel="", title="Top Genres")
# Out:
# <AxesSubplot:title={'center':'Top Genres'}>

# %%
df["month"]=df["date_added"].dt.to_period("M").dt.to_timestamp()
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             N/A
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             N/A
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df.groupby("month")["type"].size().plot(kind='line', xlabel="", ylabel="", title="Content growth over time", grid=True, figsize=(14,5))
plt.show()

# %%
content_by_time = df.groupby(["month", "type"]).size().reset_index(name="count")

# %%
content_by_time = content_by_time.pivot(index="month", columns="type", values="count")

# %%
plt.figure(figsize=(15, 4))

plt.plot(content_by_time.index, content_by_time["Movie"], label="Movies")
plt.legend()
plt.title("Content growth over time")
plt.grid(True)

plt.show()

# %%
content_by_time = df.groupby(["month", "type"]).size().reset_index(name="count")

# %%
content_by_time = content_by_time.pivot(index="month", columns="type", values="count")

# %%
plt.figure(figsize=(15,4))
plt.plot(content_by_time.index, content_by_time["Movie"], label = "Movie")
plt.plot(content_by_time.index, content_by_time["TV Show"], label = "TV shows")
plt.legend()
plt.title("Content growth over time")
plt.grid(True)
plt.show()

# %%
df["release_year"].hist(bins=10)
plt.show()

# %%
df["release_year"].value_counts().plot(kind='bar', figsize=(15,4), xlabel="", title="Content by release year")
plt.show()

# %%
df_tv_show = df[df["type"] == "TV Show"]
df_tv_show.head()
# Out:
#    show_id     type                           title director  \
# 0       s1  TV Show                              3%      N/A
# 4    s1001  TV Show                  Blue Planet II      N/A
# 10   s1007  TV Show                             BNA      N/A
# 15   s1011  TV Show                   Bo on the Go!      N/A
# 17   s1013  TV Show  Bob Ross: Beauty Is Everywhere      N/A
#
#                                                  cast         country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 4                                  David Attenborough  United Kingdom
# 10  Sumire Morohoshi, Yoshimasa Hosoya, Maria Naga...           Japan
# 15    Catherine O'Connor, Andrew Sabiston, Jim Fowler          Canada
# 17                                           Bob Ross             N/A
#
#    date_added  release_year rating  duration  \
# 0  2020-08-14          2020  TV-MA         4
# 4  2018-12-03          2017   TV-G         1
# ...

# %%
df_movies= df[df["type"] == "Movie"]
df_movies.head()
# Out:
#   show_id   type                                      title         director  \
# 1     s10  Movie                                       1920     Vikram Bhatt
# 2    s100  Movie                                 3 Heroines   Iman Brotoseno
# 3   s1000  Movie  Blue Mountain State: The Rise of Thadland     Lev L. Spiro
# 5   s1002  Movie                                  Blue Ruin  Jeremy Saulnier
# 6   s1003  Movie                                Blue Streak     Les Mayfield
#
#                                                 cast                 country  \
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...                   India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...               Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...           United States
# 5  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...   United States, France
# 6  Martin Lawrence, Luke Wilson, Peter Greene, Da...  Germany, United States
#
# ...

# %%
df_movies["duration"].hist()
# Out:
# <AxesSubplot:>

# %%
df_movies["duration"].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print(f"The median movie duration is {df_movies['duration'].median():.0f} mins")
# Out:
# The median movie duration is 98 mins

# %%
df_tv_show['duration'].hist()
# Out:
# <AxesSubplot:>

# %%
df_tv_show['duration'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
print(f"The median tv show duration is {df_tv_show['duration'].median():.0f} hour(s)")
# Out:
# The median tv show duration is 1 hour(s)
